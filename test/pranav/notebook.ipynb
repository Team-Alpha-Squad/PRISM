# %% [markdown]
# <a href="https://colab.research.google.com/github/Team-Alpha-Squad/PRISM/blob/master/test/pranav/notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##African Recession

# %% [markdown]
# Importing data

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/Team-Alpha-Squad/PRISM/master/test/pranav/data/africa_recession.csv?token=APK43YHWKRJ7AJXZUGDG5XK67R4RW"
df = pd.read_csv(url, header=None)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-40-8000c2a07d80> in <module>()
#       1 url = "https://raw.githubusercontent.com/Team-Alpha-Squad/PRISM/master/test/pranav/data/africa_recession.csv?token=APK43YHWKRJ7AJXZUGDG5XK67R4RW"
# ----> 2 df = pd.read_csv(url, header=None)
#       3
#       4
#
# ...

# %%
df.head()
# Out:
#          pop        emp  ...  fish_change  growthbucket
# 0  28.849621   6.914298  ...     0.007576             0
# 1  45.728313  13.623806  ...     0.007576             0
# 2  33.262043  13.323813  ...     0.007576             0
# 3   8.025703   3.869000  ...     0.007576             0
# 4   1.061468   0.243000  ...     0.007576             0
#
# [5 rows x 50 columns]

# %%
headers = ["Population (in millions)","Number of persons engaged (in millions)","Ratio of Employed Persons to Total Population","Human capital index, based on years of schooling and returns to education; see Human capital in PWT9...",
           "Real consumption of households and government, at current PPPs (in mil. 2011US$)","Real domestic absorption, (real consumption plus investment), at current PPPs (in mil. 2011US$)","Capital stock at current PPPs (in mil. 2011US$)","Capital services levels at current PPPs (USA=1)",
           "TFP level at current PPPs (USA=1)","Welfare-relevant TFP levels at current PPPs (USA=1)","Real consumption at constant 2011 national prices (in mil. 2011US$)","Real domestic absorption at constant 2011 national prices (in mil. 2011US$)","Capital stock at constant 2011 national prices (in mil. 2011US$)",
           "Capital services at constant 2011 national prices (2011=1)","TFP at constant national prices (2011=1)","Welfare-relevant TFP at constant national prices (2011=1)","Share of labour compensation in GDP at current national prices","Real internal rate of return","Average depreciation rate of the capital stock","Exchange rate, national currency/USD (market+estimated)","Price level of CCON (PPP/XR), price level of USA GDPo in 2011=1","Price level of CDA (PPP/XR), price level of USA GDPo in 2011=1","Price level of CGDPo (PPP/XR), price level of USA GDPo in 2011=1",
           "Share of household consumption at current PPPs","Share of gross capital formation at current PPPs","Share of government consumption at current PPPs","Share of merchandise exports at current PPPs","Share of merchandise imports at current PPPs","Share of residual trade and GDP statistical discrepancy at current PPPs","Price level of household consumption, price level of USA GDPo in 2011=1","Price level of capital formation, price level of USA GDPo in 2011=1","Price level of government consumption, price level of USA GDPo in 2011=1","Price level of exports, price level of USA GDPo in 2011=1","Price level of imports, price level of USA GDPo in 2011=1",
           "Price level of the capital stock, price level of USA in 2011=1","Annual Bank of Canada commodity price index - Total","Annual Bank of Canada commodity price index - Excluding Energy","Annual Bank of Canada commodity price index - Energy","Annual Bank of Canada commodity price index - Metals and Minerals","Annual Bank of Canada commodity price index - Forestry","Annual Bank of Canada commodity price index - Agriculture","Annual Bank of Canada commodity price index - Fish","Year-on-Year Percentage Change Annual Bank of Canada commodity price index - Total","Year-on-Year Percentage Change Annual Bank of Canada commodity price index - Excluding Energy","Year-on-Year Percentage Change Annual Bank of Canada commodity price index - Energy","Year-on-Year Percentage Change Annual Bank of Canada commodity price index - Metals and Minerals","Year-on-Year Percentage Change Annual Bank of Canada commodity price index - Forestry","Year-on-Year Percentage Change Annual Bank of Canada commodity price index - Agriculture","Year-on-Year Percentage Change Annual Bank of Canada commodity price index - Fish"," '1' = Recession; '0' = No_Recession"]

# %%
df = pd.read_csv(url,names=headers)
df
# Out:
#     Population (in millions)  ...  '1' = Recession; '0' = No_Recession
# 0                        pop  ...                         growthbucket
# 1                28.84962082  ...                                    0
# 2                45.72831345  ...                                    0
# 3                  33.262043  ...                                    0
# 4                 8.02570343  ...                                    0
# ..                       ...  ...                                  ...
# 482               12.2084074  ...                                    0
# 483              29.78419304  ...                                    1
# 484              55.79778671  ...                                    0
# 485              15.85056686  ...                                    0
# 486              7.797694206  ...                                    0
#
# [487 rows x 50 columns]

# %%
df.describe()
# Out:
#        Population (in millions)  ...  '1' = Recession; '0' = No_Recession
# count                       487  ...                                  487
# unique                      487  ...                                    3
# top                 4.420184135  ...                                    0
# freq                          1  ...                                  448
#
# [4 rows x 50 columns]
