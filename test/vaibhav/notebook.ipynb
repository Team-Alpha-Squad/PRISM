# %% [markdown]
# <a href="https://colab.research.google.com/github/Team-Alpha-Squad/PRISM/blob/master/test/vaibhav/notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##African Recession

# %% [markdown]
# Importing data

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/Team-Alpha-Squad/PRISM/master/test/pranav/data/africa_recession.csv?token=APK43YHWKRJ7AJXZUGDG5XK67R4RW"
df = pd.read_csv(url, header=None)

# %%
header_row = 0
df.columns = df.iloc[header_row]
df = df.drop(df.index[0])
df.head()
# Out:
# 0          pop          emp  ...  fish_change growthbucket
# 1  28.84962082  6.914297581  ...  0.007575845            0
# 2  45.72831345    13.623806  ...  0.007575845            0
# 3    33.262043  13.32381344  ...  0.007575845            0
# 4   8.02570343  3.868999958  ...  0.007575845            0
# 5  1.061468005  0.243000001  ...  0.007575845            0
#
# [5 rows x 50 columns]

# %%
df.describe()
# Out:
# 0               pop          emp  ...  fish_change growthbucket
# count           486          486  ...          486          486
# unique          486          480  ...           18            2
# top     19.55254173  0.268000007  ...  0.120629163            0
# freq              1            2  ...           27          448
#
# [4 rows x 50 columns]

# %%
print(df.dtypes)
# Out:
# 0
# pop                       object
# emp                       object
# emp_to_pop_ratio          object
# hc                        object
# ccon                      object
# cda                       object
# cn                        object
# ck                        object
# ctfp                      object
# cwtfp                     object
# rconna                    object
# rdana                     object
# rnna                      object
# rkna                      object
# rtfpna                    object
# rwtfpna                   object
# labsh                     object
# irr                       object
# delta                     object
# xr                        object
# pl_con                    object
# pl_da                     object
# pl_gdpo                   object
# csh_c                     object
# csh_i                     object
# csh_g                     object
# csh_x                     object
# csh_m                     object
# csh_r                     object
# pl_c                      object
# pl_i                      object
# pl_g                      object
# pl_x                      object
# pl_m                      object
# pl_n                      object
# total                     object
# excl_energy               object
# energy                    object
# metals_minerals           object
# forestry                  object
# agriculture               object
# fish                      object
# total_change              object
# excl_energy_change        object
# energy_change             object
# metals_minerals_change    object
# forestry_change           object
# agriculture_change        object
# fish_change               object
# growthbucket              object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 486 entries, 1 to 486
# Data columns (total 50 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   pop                     486 non-null    object
#  1   emp                     486 non-null    object
#  2   emp_to_pop_ratio        486 non-null    object
#  3   hc                      486 non-null    object
#  4   ccon                    486 non-null    object
#  5   cda                     486 non-null    object
#  6   cn                      486 non-null    object
#  7   ck                      486 non-null    object
#  8   ctfp                    486 non-null    object
#  9   cwtfp                   486 non-null    object
#  10  rconna                  486 non-null    object
#  11  rdana                   486 non-null    object
#  12  rnna                    486 non-null    object
#  13  rkna                    486 non-null    object
#  14  rtfpna                  486 non-null    object
#  15  rwtfpna                 486 non-null    object
#  16  labsh                   486 non-null    object
#  17  irr                     486 non-null    object
#  18  delta                   486 non-null    object
#  19  xr                      486 non-null    object
#  20  pl_con                  486 non-null    object
#  21  pl_da                   486 non-null    object
#  22  pl_gdpo                 486 non-null    object
#  23  csh_c                   486 non-null    object
#  24  csh_i                   486 non-null    object
#  25  csh_g                   486 non-null    object
#  26  csh_x                   486 non-null    object
#  27  csh_m                   486 non-null    object
#  28  csh_r                   486 non-null    object
#  29  pl_c                    486 non-null    object
#  30  pl_i                    486 non-null    object
#  31  pl_g                    486 non-null    object
#  32  pl_x                    486 non-null    object
#  33  pl_m                    486 non-null    object
#  34  pl_n                    486 non-null    object
#  35  total                   486 non-null    object
#  36  excl_energy             486 non-null    object
#  37  energy                  486 non-null    object
#  38  metals_minerals         486 non-null    object
#  39  forestry                486 non-null    object
#  40  agriculture             486 non-null    object
#  41  fish                    486 non-null    object
#  42  total_change            486 non-null    object
#  43  excl_energy_change      486 non-null    object
#  44  energy_change           486 non-null    object
#  45  metals_minerals_change  486 non-null    object
#  46  forestry_change         486 non-null    object
#  47  agriculture_change      486 non-null    object
#  48  fish_change             486 non-null    object
#  49  growthbucket            486 non-null    object
# dtypes: object(50)
# memory usage: 193.6+ KB

# %%
#df["pop"] = pd.to_numeric(df[["pop", "emp",	"emp_to_pop_ratio", "hc",	"ccon",	"cda",	"cn",	"ck",	"ctfp",	"cwtfp",	"rconna	rdana	rnna	rkna	rtfpna	rwtfpna	labsh	irr	delta	xr	pl_con	pl_da	pl_gdpo	csh_c	csh_i	csh_g	csh_x	csh_m	csh_r	pl_c	pl_i	pl_g	pl_x	pl_m	pl_n	total	excl_energy	energy	metals_minerals	forestry	agriculture	fish	total_change	excl_energy_change	energy_change	metals_minerals_change	forestry_change	agriculture_change	fish_change])
df.iloc[:] = df.iloc[:].astype(float)
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 486 entries, 1 to 486
# Data columns (total 50 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   pop                     486 non-null    float64
#  1   emp                     486 non-null    float64
#  2   emp_to_pop_ratio        486 non-null    float64
#  3   hc                      486 non-null    float64
#  4   ccon                    486 non-null    float64
#  5   cda                     486 non-null    float64
#  6   cn                      486 non-null    float64
#  7   ck                      486 non-null    float64
#  8   ctfp                    486 non-null    float64
#  9   cwtfp                   486 non-null    float64
#  10  rconna                  486 non-null    float64
#  11  rdana                   486 non-null    float64
#  12  rnna                    486 non-null    float64
#  13  rkna                    486 non-null    float64
#  14  rtfpna                  486 non-null    float64
#  15  rwtfpna                 486 non-null    float64
#  16  labsh                   486 non-null    float64
#  17  irr                     486 non-null    float64
#  18  delta                   486 non-null    float64
#  19  xr                      486 non-null    float64
#  20  pl_con                  486 non-null    float64
#  21  pl_da                   486 non-null    float64
#  22  pl_gdpo                 486 non-null    float64
#  23  csh_c                   486 non-null    float64
#  24  csh_i                   486 non-null    float64
#  25  csh_g                   486 non-null    float64
#  26  csh_x                   486 non-null    float64
#  27  csh_m                   486 non-null    float64
#  28  csh_r                   486 non-null    float64
#  29  pl_c                    486 non-null    float64
#  30  pl_i                    486 non-null    float64
#  31  pl_g                    486 non-null    float64
#  32  pl_x                    486 non-null    float64
#  33  pl_m                    486 non-null    float64
#  34  pl_n                    486 non-null    float64
#  35  total                   486 non-null    float64
#  36  excl_energy             486 non-null    float64
#  37  energy                  486 non-null    float64
#  38  metals_minerals         486 non-null    float64
#  39  forestry                486 non-null    float64
#  40  agriculture             486 non-null    float64
#  41  fish                    486 non-null    float64
#  42  total_change            486 non-null    float64
#  43  excl_energy_change      486 non-null    float64
#  44  energy_change           486 non-null    float64
#  45  metals_minerals_change  486 non-null    float64
#  46  forestry_change         486 non-null    float64
#  47  agriculture_change      486 non-null    float64
#  48  fish_change             486 non-null    float64
#  49  growthbucket            486 non-null    float64
# dtypes: float64(50)
# memory usage: 193.6 KB
# None

# %%
df.corr(method ='pearson')
import seaborn as sb
sb.heatmap(df, 
            xticklabels=df.columns,
            yticklabels=df.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=0.5)
# Out:
# Error in callback <function flush_figures at 0x7f034bfba378> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/pylab/backend_inline.py in flush_figures()
#     115         # ignore the tracking, just draw and close all figures
#     116         try:
# --> 117             return show(True)
#     118         except Exception as e:
#     119             # safely show traceback if in IPython, else raise
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/display.py in display(*objs, **kwargs)
#     304             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     305         else:
# --> 306             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     307             if not format_dict:
#     308                 # nothing to display (e.g. _ipython_display_ took over)
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     171             md = None
#     172             try:
# --> 173                 data = formatter(obj)
#     174             except:
#     175                 # FIXME: log the exception
#
# <decorator-gen-9> in __call__(self, obj)
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     215     """show traceback on failed format call"""
#     216     try:
# --> 217         r = method(self, *args, **kwargs)
#     218     except NotImplementedError:
#     219         # don't warn on NotImplementedErrors
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     332                 pass
#     333             else:
# --> 334                 return printer(obj)
#     335             # Finally look for special method names
#     336             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     239
#     240     if 'png' in formats:
# --> 241         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     242     if 'retina' in formats or 'png2x' in formats:
#     243         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     123
#     124     bytes_io = BytesIO()
# --> 125     fig.canvas.print_figure(bytes_io, **kw)
#     126     data = bytes_io.getvalue()
#     127     if fmt == 'svg':
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2101                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#    2102                     bbox_inches = self.figure.get_tightbbox(renderer,
# -> 2103                             bbox_extra_artists=bbox_artists)
#    2104                     pad = kwargs.pop("pad_inches", None)
#    2105                     if pad is None:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    2383
#    2384         for a in artists:
# -> 2385             bbox = a.get_tightbbox(renderer)
#    2386             if bbox is not None and (bbox.width != 0 or bbox.height != 0):
#    2387                 bb.append(bbox)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists)
#    4359                     # this artist
#    4360                     continue
# -> 4361             bbox = a.get_tightbbox(renderer)
#    4362             if (bbox is not None
#    4363                     and 0 < bbox.width < np.inf
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/artist.py in get_tightbbox(self, renderer)
#     280             The enclosing bounding box (in figure pixel co-ordinates).
#     281         """
# --> 282         bbox = self.get_window_extent(renderer)
#     283         if self.get_clip_on():
#     284             clip_box = self.get_clip_box()
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/text.py in get_window_extent(self, renderer, dpi)
#     903             raise RuntimeError('Cannot get window extent w/o renderer')
#     904
# --> 905         bbox, info, descent = self._get_layout(self._renderer)
#     906         x, y = self.get_unitless_position()
#     907         x, y = self.get_transform().transform((x, y))
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/text.py in _get_layout(self, renderer)
#     298             if clean_line:
#     299                 w, h, d = renderer.get_text_width_height_descent(
# --> 300                     clean_line, self._fontproperties, ismath=ismath)
#     301             else:
#     302                 w = h = d = 0
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     211
#     212         flags = get_hinting_flag()
# --> 213         font = self._get_agg_font(prop)
#     214         font.set_text(s, 0.0, flags=flags)
#     215         w, h = font.get_width_height()  # width and height of unrotated string
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py in _get_agg_font(self, prop)
#     245         Get the font for text instance t, caching for efficiency
#     246         """
# --> 247         fname = findfont(prop)
#     248         font = get_font(fname)
#     249
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/font_manager.py in findfont(self, prop, fontext, directory, fallback_to_default, rebuild_if_missing)
#    1220         rc_params = tuple(tuple(rcParams[key]) for key in [
#    1221             "font.serif", "font.sans-serif", "font.cursive", "font.fantasy",
# -> 1222             "font.monospace"])
#    1223         return self._findfont_cached(
#    1224             prop, fontext, directory, fallback_to_default, rebuild_if_missing,
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/font_manager.py in <genexpr>(.0)
#    1218         # _findfont_cached so to prevent using a stale cache entry after an
#    1219         # rcParam was changed.
# -> 1220         rc_params = tuple(tuple(rcParams[key]) for key in [
#    1221             "font.serif", "font.sans-serif", "font.cursive", "font.fantasy",
#    1222             "font.monospace"])
#
# KeyboardInterrupt:
